# %% [markdown]
#  ## Часть 3. Кластеризация. ##

# %% [markdown]
# ### 1. Загрузка и преобразование данных

# %%
# загрузим необходимые библиотеки
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
from scipy.spatial.distance import cdist
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn import cluster
from sklearn.cluster import KMeans
from sklearn.cluster import SpectralClustering
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN
from sklearn.mixture import GaussianMixture
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from tools.clusters import plot_metrics
from tools.clusters import plot_coef
from sklearn import metrics
from sklearn.metrics import rand_score 
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score
from sklearn.metrics import homogeneity_score
from sklearn.metrics import completeness_score

# %%
# загрузим датасет с отобранными для анализа признаками
model_df = pd.read_csv(
    './data/model_df.csv', index_col='region')

# %%
# произведем стандартизацию признаков с помощью StandardScaler
stand_scaler = StandardScaler()
scaler_df = stand_scaler.fit_transform(model_df)
scaler_df.shape
# Out:
# (85, 9)

# %% [markdown]
# ### 2. Определение оптимальных параметров и внутренних метрик модели ML.

# %%
plot_metrics(scaler_df)

# %% [markdown]
# "Метод локтя" при оценке инерции и коэффициент Калински-Харабаса указывают на оптимальное количество кластеров равное 4.Тогда как коэффициент 'силуэта' указывает на 5 кластеров, а коэффициент Дэвиса-Болдина на 6 кластеров. Примем значение числа кластеров равное 4.
# Для сбора метрик моделей проекта в таблицу создадим списки моделей и метрик моделей.
# Отобразим проекцию  семимерного признакового пространства  на плоскость используя t-SNE преобразование. Кроме того выведем значения кофициентов "силуэта", Калински-Харабаса и Дэвиса-Болдина для количества кластеров - 4.
# Примем модель Kmeans за базовую для сравнения ее с другими моделями кластеризации. Метрикой оценки модели выберем rand_score (Индекс Рэнда рассчитывает меру сходства между двумя кластерингами,рассматривая все пары выборок и подсчитывая пары,которые приписываются одним и тем же или разным кластерам в предсказанных и истинных кластерингах. )

# %%
models=[]  # список моделей
silhouette=[] # список коэффициентов "силуэта" моделей
calinski_harabasz=[] # список коэффициентов Калински-Харабаса моделей
davies_bouldin=[] # список коэффициентов Дэвиса_Болдина моделей
rand=[1.0] # список индексов Рэнда

def make_metrics_lists(df,labels):    
    coef_silhouette = silhouette_score(df, labels)  
    coef_calinski_harabasz = calinski_harabasz_score(df, labels)  
    coef_davies_bouldin = davies_bouldin_score(df, labels)
    
    silhouette.append(coef_silhouette)
    calinski_harabasz.append(coef_calinski_harabasz)
    davies_bouldin.append(coef_davies_bouldin)

# %%
kmeans = KMeans(n_clusters=4, random_state=42)
bm_kmeans = kmeans.fit_predict(scaler_df)
plot_coef(scaler_df, kmeans.labels_)
make_metrics_lists(scaler_df, kmeans.labels_)
models.append(bm_kmeans)
# Out:
# Коэфициент силуэта: 0.452
# Коэфициент Калински-Харабаса: 30.592
# Коэфициент Дэвиса-Болдина: 0.931

# %% [markdown]
# Уменьшим размерность данных методом главных компонент (PCA - principal component analysis). Найдем число главных компонент описывающих 90% дисперсии признакового поля данных. Алгоритм вычисления ***svd_solver*** выберем 'full'

# %%
pca = PCA(n_components=0.9, svd_solver='full')
pca_df = pca.fit_transform(scaler_df)
plot_metrics(pca_df)
print(f'Число главных компонент: {pca.n_components_}')
# Out:
# Число главных компонент: 6

# %% [markdown]
# Количество главных компонент описывающих 90% дисперсии признаков оказалось равным 6. Применение метода главных компонент увеличило величину коэффициентов и незначительно изменило общую картину. Оставляем количество кластеров равное 4.

# %%
pca_kmeans = KMeans(n_clusters=4, random_state=42)
pca_kmeans.fit_predict(pca_df)
index_rand = rand_score(bm_kmeans, pca_kmeans.labels_)
plot_coef(pca_df, pca_kmeans.labels_)
make_metrics_lists(pca_df, pca_kmeans.labels_)
print('Индекс Рэнда (сравнение с базовой моделью): %.3f' % index_rand)
models.append(pca_kmeans)
rand.append(index_rand)
# Out:
# Коэфициент силуэта: 0.343
# Коэфициент Калински-Харабаса: 34.038
# Коэфициент Дэвиса-Болдина: 0.985
# Индекс Рэнда (сравнение с базовой моделью): 0.803

# %% [markdown]
# ### 3. Сравнение с другими алгоритмами кластеризации ###
#
# #### 3.1. Спектральная кластеризация

# %%
spectral = SpectralClustering(n_clusters=4)
labels = spectral.fit_predict(pca_df)
index_rand = rand_score(bm_kmeans, spectral.labels_)
plot_coef(pca_df, spectral.labels_)
make_metrics_lists(pca_df, spectral.labels_)
print('Индекс Рэнда (сравнение с базовой моделью): %.3f' % index_rand)
models.append(spectral)
rand.append(index_rand)
# Out:
# Коэфициент силуэта: 0.530
# Коэфициент Калински-Харабаса: 21.285
# Коэфициент Дэвиса-Болдина: 0.961
# Индекс Рэнда (сравнение с базовой моделью): 0.824

# %% [markdown]
# #### 3.2. Агломеративная кластеризация

# %%
# наилучший вариант: linkage='ward'
agg_clust= AgglomerativeClustering(n_clusters=4, linkage='ward')
labels = agg_clust.fit_predict(pca_df)
index_rand = rand_score(bm_kmeans, agg_clust.labels_)
plot_coef(pca_df, agg_clust.labels_)
make_metrics_lists(pca_df, agg_clust.labels_)
print('Индекс Рэнда (сравнение с базовой моделью): %.3f' % index_rand)
models.append(agg_clust)
rand.append(index_rand)
# Out:
# Коэфициент силуэта: 0.462
# Коэфициент Калински-Харабаса: 33.369
# Коэфициент Дэвиса-Болдина: 0.925
# Индекс Рэнда (сравнение с базовой моделью): 0.959

# %% [markdown]
# #### 3.3. Гауссова смесь

# %%
gaus_mix = GaussianMixture(
    n_components=4,
    random_state=42,
    covariance_type='tied'
)
labels = gaus_mix.fit_predict(pca_df)
index_rand = rand_score(bm_kmeans, labels)
plot_coef(pca_df, labels)
make_metrics_lists(pca_df, labels)
print('Индекс Рэнда (сравнение с базовой моделью): %.3f' % index_rand)
models.append(agg_clust)
rand.append(index_rand)
# Out:
# Коэфициент силуэта: 0.470
# Коэфициент Калински-Харабаса: 25.783
# Коэфициент Дэвиса-Болдина: 0.943
# Индекс Рэнда (сравнение с базовой моделью): 0.933

# %% [markdown]
# ### 4. Итоговая таблица метрик.
#
# Построим для наглядности итоговую таблицу метрик:

# %%
d = {'model':['Base Kmeans','Kmeans+PSA', 'SpectralClustering+PCA',
              'AgglomerativeClustering+PCA', 'GaussianMixture+PCA'], 
                                          'Коэф."силуэта"': silhouette,
                                          'Коэф. Калински-Харабаса':calinski_harabasz,
                                          'Коэф. Дэвис-Болдина':davies_bouldin,
                                          'Индекс Рэнда':rand}
metrics_table = pd.DataFrame.from_dict(d, orient='index').T 
metrics_table
# Out:
#                          model Коэф."силуэта" Коэф. Калински-Харабаса  \
# 0                  Base Kmeans        0.45172               30.592393
# 1                   Kmeans+PSA        0.45172               30.592393
# 2       SpectralClustering+PCA       0.343304               34.038253
# 3  AgglomerativeClustering+PCA       0.530454               21.284718
# 4          GaussianMixture+PCA       0.462075               33.368761
# 5                          NaN       0.469934               25.782589
#
#   Коэф. Дэвис-Болдина Индекс Рэнда
# 0            0.931014          1.0
# 1            0.931014     0.802801
# 2            0.984628      0.82409
# 3            0.961367     0.958824
# 4              0.9254     0.932773
# 5             0.94318          NaN

# %% [markdown]
# В совокупности метрик кластеризации наилучший результат дает Агломеративноая кластеризация с понижением размерности методом главных компонент. Значение коэффициента "силуэта" достаточно большое среди наибольших значений (0.46), коэффициент Калински-Харабаса один из наибольших, коэфицциент Дэвиса-Болдина имеет минимальное значение.
#
# Альтернативным вариантом кластеризации может являться KMeans с применением понижения размерности методом главных компонент.

# %% [markdown]
# ### 5. Сохранение модели кластеризации и датафрейма с метками кластеров. ####

# %%
 '''В модели применим следующие этапы:
        - StandardScaler: стандартизация признакового поля данных;
        - PCA: понижение размерности методом главных компонент с сохранением дисперсии признаков 90%;
        - SpectralClustering: спектральная кластеризация.
'''
pipe = Pipeline([('scaler', StandardScaler()), ('pca', PCA(n_components=0.9, svd_solver='full')), ('agg_clust', AgglomerativeClustering(n_clusters=4))])

# сохраним модель в виде pickle-файла
with open('data/model.pkl', 'wb') as n:
    pickle.dump(pipe, n)
    
# создадим метки кластеров
agg_clust= AgglomerativeClustering(n_clusters=4, linkage='ward')
model_df['cluster'] = agg_clust.fit_predict(pca_df) # метки кластеров

# упорядочим нумерацию кластеров по количеству регионов
model_df['cluster'] = model_df['cluster'].replace({3:0, 0:1, 2:2, 1:3})

# сохраним датафрейм с метками кластеров
model_df['cluster'].to_csv('./data/labels.csv')

# сохраним метки кластеров
model_df.to_csv('./data/df_labels.csv')

# %% [markdown]
# ### 6. Характеристика полученных кластеров

# %%
model_df.head()
# Out:
#                                           density  living_area      gdpp  \
# region
# Алтайский край                          13.792906         18.0  291156.9
# Амурская область                         2.182997         17.3  571362.1
# Архангельская область без Ненецкого АО   2.644435         16.9  514200.4
# Астраханская область                    20.516115         19.2  526950.9
# Белгородская область                    57.092614         17.8  646569.0
#
#                                         spec_subsidies  welfare  retail  \
# region
# Алтайский край                            32067.902020     29.7  153605
# Амурская область                          43050.621924     21.7  245233
# Архангельская область без Ненецкого АО    38856.664512     21.4  250033
# Астраханская область                      23911.906335     31.4  174527
# Белгородская область                      22929.918673     16.1  237076
#
#                                         poverty_percent  living_wage  \
# ...

# %%
model_df['cluster'].value_counts().sort_index()
# Out:
# cluster
# 0     2
# 1     9
# 2    65
# 3     9
# Name: count, dtype: int64

# %%
# Кластер 0

cluster_0 = list(model_df[model_df['cluster'] == 0].index)
print (', '.join(cluster_0))
# Out:
# Москва, Санкт-Петербург

# %%
model_df[model_df['cluster'] == 0].describe()
# Out:
#            density  living_area          gdpp  spec_subsidies    welfare  \
# count     2.000000     2.000000  2.000000e+00        2.000000   2.000000
# mean   4398.978084    14.750000  1.269401e+06    16387.219693  18.650000
# std     779.886114     1.343503  4.217799e+05     9002.478735   1.626346
# min    3847.515324    13.800000  9.711580e+05    10021.505932  17.500000
# 25%    4123.246704    14.275000  1.120280e+06    13204.362813  18.075000
# 50%    4398.978084    14.750000  1.269401e+06    16387.219693  18.650000
# 75%    4674.709464    15.225000  1.418523e+06    19570.076573  19.225000
# max    4950.440843    15.700000  1.567645e+06    22752.933454  19.800000
#
#               retail  poverty_percent  living_wage  unemployment_rate  cluster
# count       2.000000         2.000000      2.00000           2.000000      2.0
# mean   346084.000000         5.950000  16667.00000           2.750000      0.0
# ...

# %%
# Кластер 1

cluster_1 = list(model_df[model_df['cluster'] == 1].index)
print (', '.join(cluster_1))
# Out:
# Камчатский край, Магаданская область, Московская область, Ненецкий автономный округ, Республика Саха (Якутия), Сахалинская область, Ханты-Мансийский автономный округ - Югра, Чукотский автономный округ, Ямало-Ненецкий автономный округ

# %%
model_df[model_df['cluster'] == 1].describe()
# Out:
#           density  living_area          gdpp  spec_subsidies    welfare  \
# count    9.000000     9.000000  9.000000e+00        9.000000   9.000000
# mean    20.505726    15.844444  2.396298e+06   149160.067202  14.033333
# std     57.400587     2.237248  1.658955e+06   178869.983207   3.795721
# min      0.069701    13.800000  6.838451e+05    15884.903836   6.400000
# 25%      0.303048    14.100000  1.168152e+06    34439.947894  12.600000
# 50%      0.674204    15.500000  2.035007e+06   124582.304442  14.400000
# 75%      3.131400    16.500000  2.404271e+06   184944.168846  16.500000
# max    173.495071    20.900000  5.206287e+06   583593.839079  19.400000
#
#               retail  poverty_percent   living_wage  unemployment_rate  \
# count       9.000000         9.000000      9.000000           9.000000
# mean   261080.777778         9.522222  19711.555556           4.955556
# std     50587.355727         3.930260   3433.679008           2.104823
# ...

# %%
# Кластер 2

cluster_2 = list(model_df[model_df['cluster'] == 2].index)
print (', '.join(cluster_2))
# Out:
# Алтайский край, Амурская область, Архангельская область без Ненецкого АО, Астраханская область, Белгородская область, Брянская область, Владимирская область, Волгоградская область, Вологодская область, Воронежская область, Забайкальский край, Ивановская область, Иркутская область, Калининградская область, Калужская область, Кемеровская область, Кировская область, Костромская область, Краснодарский край, Красноярский край, Курганская область, Курская область, Ленинградская область, Липецкая область, Мурманская область, Нижегородская область, Новгородская область, Новосибирская область, Омская область, Оренбургская область, Орловская область, Пензенская область, Пермский край, Приморский край, Псковская область, Республика Адыгея, Республика Башкортостан, Республика Бурятия, Республика Карелия, Республика Коми, Республика Крым, Республика Марий Эл, Республика Мордовия, Республика Северная Осетия-Алания, Республика Татарстан, Республика Хакасия, Ростовская область, Рязанская область, Са
# ...

# %%
model_df[model_df['cluster'] == 2].describe()
# Out:
#           density  living_area          gdpp  spec_subsidies    welfare  \
# count   65.000000    65.000000  6.500000e+01       65.000000  65.000000
# mean    35.446899    17.189231  4.675684e+05    30673.194313  23.527692
# std     64.649187     1.671930  1.561295e+05    15518.806728   3.792983
# min      1.050023    13.700000  2.678144e+05    11601.288549  12.600000
# 25%     10.944900    16.200000  3.584804e+05    21241.816509  22.400000
# 50%     27.765516    17.000000  4.596295e+05    25924.555062  23.500000
# 75%     41.800820    18.000000  5.389719e+05    36074.964471  25.500000
# max    519.835648    24.100000  1.072337e+06    95253.945962  31.400000
#
#               retail  poverty_percent   living_wage  unemployment_rate  \
# count      65.000000        65.000000     65.000000          65.000000
# mean   197459.800000        13.343077  11944.446154           6.244615
# std     36535.345216         3.099948   1620.847059           1.890604
# ...

# %%
# Кластер 3

cluster_3 = list(model_df[model_df['cluster'] == 3].index)
print (', '.join(cluster_3))
# Out:
# Еврейская автономная область, Кабардино-Балкарская Республика, Карачаево-Черкесская Республика, Республика Алтай, Республика Дагестан, Республика Ингушетия, Республика Калмыкия, Республика Тыва, Чеченская Республика

# %%
model_df[model_df['cluster'] == 3].describe()
# Out:
#           density  living_area           gdpp  spec_subsidies    welfare  \
# count    9.000000     9.000000       9.000000        9.000000   9.000000
# mean    47.803985    18.744444  250171.155556    69468.065905  28.433333
# std     54.703854     4.588603   82201.194441    26565.376886   5.256900
# min      1.941727    13.600000  142199.700000    43277.951579  19.800000
# 25%      3.628146    14.400000  207471.500000    50558.886180  24.300000
# 50%     32.606850    18.900000  239640.700000    60147.182996  28.300000
# 75%     69.635124    20.200000  283451.400000    81543.922835  32.500000
# max    162.363433    27.800000  400340.500000   123345.463346  35.100000
#
#               retail  poverty_percent   living_wage  unemployment_rate  \
# count       9.000000         9.000000      9.000000           9.000000
# mean   118591.555556        23.822222  11739.333333          15.744444
# std     46829.731715         4.939326   1773.523823           6.592441
# ...

# %%
title=['Плотность населения; чел./кв.км.','Средняя жилая площадь ; кв.м./чел.',
       'Валовой региональный продукт; руб./чел.', 'Федеральные дотации; руб/чел.',
       'Расходы на социальную политику; %', 'Объем розничной торговли; млн.руб./чел.',
       'Доля малообеспеченного населения; %', 'Прожиточный минимум; руб./чел.',
       'Уровень безработицы; %']

cols = model_df[
    [
        'density',
        'living_area',
        'gdpp',
        'spec_subsidies',
        'welfare',
        'retail',
        'poverty_percent',
        'living_wage',
        'unemployment_rate'        
    ]
].columns.tolist()
plt.figure(figsize=(15, 25))

for i, variable in enumerate(cols):
    plt.subplot(9, 3, i + 1)
    sns.barplot(x=model_df['cluster'], y=model_df[variable], palette="winter")
    plt.tight_layout()
    plt.title(title[i].upper(), fontsize = 10)
plt.show()

# %% [markdown]
# Проанализировав статистические характеристики кластеров, сравнив их между собой и для наглядности отобразив их в виде столбчатых диагарамм можно дать следующую характеристику кластерам:
#
#  * ***кластер_0*** - самый небольшой кластер (2 города федерального значения - Москва и Санкт_Петербург), с плотностью населения ( 4399 чел./кв.км.), с высокими средними показателями дохода, валового регионального продукта на душу населения, самым высоким показателем розничной торговли, минимальной долей населения за чертой бедности, большими расходами на социальную политику и минимальным уровнем безработицы (2,8 % населения).
#
#  * ***кластер_1*** - количество субъектов - 9, с небольшой плотностью населения (20,5 чел./кв.км.), с самыми высокими средними показателями валового регионального продукта, федеральной дотации, прожиточного минимума, высоким средним показателем розничной торговли, небольшой долей малообеспеченного населения, минимальными расходами на социальную политику и не большим уровенем безработицы (4,9 % населения);
#
#  * ***кластер_2*** - самый большой по количеству объектов кластер(65), с плотностью населения (35,4 чел./кв.км.), с средними показателями валового регионального продукта, розничной торговли, доли малообеспеченного населения, большими расходами на социальную политику и не большим уровенем безработицы (6,2 % населения);
#
#  * ***кластер_3*** - количество субъектов - 9 , с средней плотностью населения ( 47,8 чел./кв.км.), минимальным показателем валового регионального продукта, розничной торговли, средними показателями федеральных дотаций, прожиточного минимума, очень высокими показателями малообеспеченного населения, расходами на социальную политику  и уровня безработицы (15,7 % населения).
#
#  Исходя из характеристики кластеров можно принять разделение регионов по уровню социального благополучия:
#
#    * ***кластер_0*** - субъекты с очень высоким уровнем;
#
#    * ***кластер_1*** - субъекты с высоким уровнем;
#
#    * ***кластер_2*** - субъекты с средним уровнем;
#
#    * ***кластер_3*** - субъекты с низким уровнем.

# %% [markdown]
# ### 7. Проверка гипотез ###
#
# Загрузим датафрейм с 52 признаками, присвоим регионам метки кластеров и сравним значения некоторых признаков между кластерами:

# %%
#  загрузим данные проекта в df
df = pd.read_csv(
    'data/sp_df_2020.csv', index_col='region')

df['cluster'] = model_df['cluster']
df.head(3)
# Out:
#                                         population    area  living_area  \
# region
# Алтайский край                             2317153  167996         18.0
# Амурская область                            790044  361908         17.3
# Архангельская область без Ненецкого АО     1092424  413103         16.9
#
#                                         per_capita  real_incomes  formal_wage  \
# region
# Алтайский край                               23864          95.5        30072
# Амурская область                             35499         100.3        52430
# Архангельская область без Ненецкого АО       34852          98.4        52779
#
#                                         real_pay      gdpp        income  \
# region
# Алтайский край                             103.8  291156.9  56637.879730
# Амурская область                           105.2  571362.1  51571.555319
# Архангельская область без Ненецкого АО     102.9  514200.4  52963.993010
#
# ...

# %% [markdown]
# #### 7.1. Проверим влияет ли число детей, пенсионеров и других социально уязвимых групп на уровень бедности в регионе

# %%
# построим столбчатые диаграммы социальных признаков детей, пенсионеров 
# и инвалидов трудоспособного возраста сгруппированных по кластерам

title=['Доля детей в регионе; чел',
       'Расходы на социальную политику; %',
       'Доля детей нуждаются в устройстве в семьи; %',
       'Доля детей устроенных в семьи от нуждающихся; %',
       'Доля детей среди малообеспеченных; %',
       'Рождаемость; чел./1000',
       'Смертность детей на первом году жизни; чел./1000',
       'Доля пенсионеров в регионе; %',
       'Доля малоимущих людей пенсионного возраста; %',
       'Число инвалидов трудового возраста; чел./1000'
    ]

cols = df[
    ['childrens_percent',
     'welfare',
     'child_orphanage_percent',
     'child_adopted',
     'ps_child',
     'newborn_1000',
     'child_mortality_1000',
     'pensioners_percent',
     'ps_pens',
     'disabled_1000'
    ]
].columns.tolist()
plt.figure(figsize=(10, 20))

for i, variable in enumerate(cols):
    plt.subplot(6, 2, i + 1)
    sns.barplot(x=df['cluster'], y=df[variable], palette="winter")
    plt.tight_layout()
    plt.title(title[i].upper(), fontsize = 10)
plt.show()

# %% [markdown]
# Графики показывают непосредственное влияние количества детей, пенсионеров, инвалидов трудоспособного возраста, рождаемости и детской смертности на уровень социального благополучия субъекта РФ.
# Так, лидером в доле детей от общего населения региона, доле детей среди малообеспеченных, рождаемости и детской смертности на первом году жизни является группа регионов с низким социальным благополучием. В данных регионах наблюдается наибольшая доля детей устроенных в семьи среди нуждающихся в устройстве из-за очень высоких расходов на социальную политику.
# Лидером доли детей нуждающихся в устройстве в семьи являются регионы с высоким уровнем социального благополучия. Происходит это по причине самых низких расходов на социальную политику и неудовлетворительной социальной программе поддержки семьи в регионе.
# Лидером доли пенсионеров от населения и доли пенсионеров среди малообеспеченных региона являются регионы с очень высоким уровнем социального благополучия. Объясняется это достаточно большими расходами на социальную политику, уровнем жизни в регионе. Минимальная доля пенсионеров от населения региона наблюдается в регионах с низким уровнем социального благополучия. Объясняется это тем, что пенсионеры выбирают для жизни более благоустроенные регионы или продолжительность жизни в регионах с низким уровнем благополучия существенно ниже.
# Лидером в количестве инвалидов трудоспособного возраста является группа регионов с низким социальным благополучием. Связанно это с тяжелыми условиями труда и большой долей трдоспособного населения.

# %% [markdown]
# #### 7.2. Проверим связан ли уровень социального благополучия с производством и потреблением в регионе

# %%
# построим столбчатые диаграмы признаков регионального производства и  
# потребления сгруппированных по кластерам

title=['Валовой региональный продукт; руб./чел.',
       'Объем розничной торговли; млн.руб./чел.',
       'Объем добычи полезных ископаемых; руб.',
       'Объем добычи полезных ископаемых на душу населения; руб.',
       'Объем обрабатывающих производств; руб.',
       'Объем обрабатывающих производств на душу населения; руб.',
       'Объем промышленного производства; руб.',
       'Объем промышленного производства на душу населения; руб.',
       'Объем водоснабжения, организации сбора и утилизации отходов; руб.',
       'Объем водосн., орг. сбора и утил-ии отходов на душу населения; руб.',
       'Объем обеспечения электроэнергией, газом и паром; руб.',
       'Объем обеспечения электроэнергией, газом и паром на душу населения; руб.',
       'Общий объем регионального производства; руб.',
       'Общий объем регионального производства на душу населения; руб.'
    ]

cols = df[
    ['gdpp',
     'retail',
     'mining',
     'spec_mining',
     'manufact',
     'spec_manufact',
     'indust',
     'spec_indust',
     'water_supply',
     'spec_water_supply',
     'provision',
     'spec_provision',
     'reg_prod_total',
     'spec_reg_prod'
    ]
].columns.tolist()
plt.figure(figsize=(10, 30))

for i, variable in enumerate(cols):
    plt.subplot(14, 2, i + 1)
    sns.barplot(x=df['cluster'], y=df[variable], palette="winter")
    plt.tight_layout()
    plt.title(title[i].upper(), fontsize = 10)
plt.show()

# %% [markdown]
# Графики доказывают влияние на уровень социального благополучия регионального производства и потребления.
# Лидером во всех отраслях регионального производства являются регионы с очень высоким уровнем социального благополучия. Происходит это из-за формирования федерального бюджета в г. Москва и оказания услуг в обслуживании региональных производств.
# При оценке отраслей регионального производства на душу населения становятся очевидными причины уровня регионов с высоким уровнем социального благополучия. В этих регионах наивысшие значения показателей отраслей регионального производства и валового регионального продукта.
# Регионы с низким уровнем  социального благополучия имеют самые низкие значения показателей всех отраслей регионального производства на душу населения.

# %% [markdown]
# #### 7.3. Проверим связан ли уровень социального благополучия с заболеваемостью в регионе

# %%
# построим столбчатые диаграммы признаков заболеваемости сгруппированных по кластерам

title=['численность населения региона; чел.',
       'Плотность населения региона; чел./кв.км.',
       'Число заболеваний установленных впервые',
       'Число заболеваний установленных впервые на 1000 чел.',
       'Число респираторных заболеваний на 1000 чел',
       'Число онкологических заболеваний на 1000 чел.'
       ]

cols = df[
    ['population',
     'density',
     'morbidity',
     'morbidity_1000',
     'respiratory',
     'neoplasms'
     ]
].columns.tolist()
plt.figure(figsize=(10, 15))

for i, variable in enumerate(cols):
    plt.subplot(6, 2, i + 1)
    sns.barplot(x=df['cluster'], y=df[variable], palette="winter")
    plt.tight_layout()
    plt.title(title[i].upper(), fontsize = 10)
plt.show()

# %% [markdown]
# Графики показывают отсутствие связи заболеваемости с социальным благополучием регионов. Видно, что заболеваемость напрямую связанна с числом и плотностью населения.
